# %% [markdown]
# ### 1.Implement logistic regression using Python/R to perform classification on Social_Network_Ads.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Reca l
# on the given dataset.

# %%
import pandas as pd

# %%
data = pd.read_csv("Social_Network_Ads.csv")

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# ### Type conversion

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coder = LabelEncoder()

# %%
data['Gender'] = coder.fit_transform(data['Gender'])

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    int32
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int32(1), int64(4)
# memory usage: 14.2 KB

# %%
Y = data['Purchased']

# %%
data.drop('Purchased' , axis=1 , inplace=True)

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 0    15624510       1   19            19000
# 1    15810944       1   35            20000
# 2    15668575       0   26            43000
# 3    15603246       0   27            57000
# 4    15804002       1   19            76000
# ..        ...     ...  ...              ...
# 395  15691863       0   46            41000
# 396  15706071       1   51            23000
# 397  15654296       0   50            20000
# 398  15755018       1   36            33000
# 399  15594041       0   49            36000
#
# [400 rows x 4 columns]

# %%
X= data.copy()

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LogisticRegression as LR

# %%
xTrain , xTest , yTrain , yTest = tts ( X , Y , test_size=0.2 , random_state = 42)

# %%
model = LR()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(xTrain , yTrain)
# Out:
# LogisticRegression()

# %%
yPred = model.predict(xTest)

# %%
from sklearn.metrics import confusion_matrix , recall_score , accuracy_score , precision_score , r2_score

# %%
cm = confusion_matrix(yTest , yPred)

# %%
cm
# Out:
# array([[50,  2],
#        [ 7, 21]], dtype=int64)

# %%
ac = accuracy_score(yTest , yPred)

# %%
ac
# Out:
# 0.8875

# %%
e = 1-ac
e
# Out:
# 0.11250000000000004

# %%
rs = recall_score(yTest , yPred)

# %%
rs
# Out:
# 0.75

# %%
ps = precision_score(yTest , yPred)

# %%
ps
# Out:
# 0.9130434782608695

# %%
r2s = r2_score(yTest , yPred)

# %%
r2s
# Out:
# 0.5054945054945056
